# %% [markdown]
# # Analyses des features

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.dates import date2num
import seaborn as sns
import datetime

# %%
df = pd.read_csv("../Datas/train.csv")

# %%
df.head(5)
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %% [markdown]
# ## Analyses des types de donnée

# %%
df.dtypes
# Out:
# datetime       object
# season          int64
# holiday         int64
# workingday      int64
# weather         int64
# temp          float64
# atemp         float64
# humidity        int64
# windspeed     float64
# casual          int64
# registered      int64
# count           int64
# dtype: object

# %% [markdown]
# Feature datetime au format texte
# Le reste, features numériques

# %% [markdown]
# ### Analyse de Datetime

# %%
df.datetime.head()
# Out:
# 0    2011-01-01 00:00:00
# 1    2011-01-01 01:00:00
# 2    2011-01-01 02:00:00
# 3    2011-01-01 03:00:00
# 4    2011-01-01 04:00:00
# Name: datetime, dtype: object

# %% [markdown]
# Format de type date => à transformer judicieusement en entier
# Relevé d'heure en heure

# %% [markdown]
# ### Analyse des features numériques

# %%
df.describe()
# Out:
#              season       holiday    workingday       weather         temp  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.00000
# mean       2.506614      0.028569      0.680875      1.418427     20.23086
# std        1.116174      0.166599      0.466159      0.633839      7.79159
# min        1.000000      0.000000      0.000000      1.000000      0.82000
# 25%        2.000000      0.000000      0.000000      1.000000     13.94000
# 50%        3.000000      0.000000      1.000000      1.000000     20.50000
# 75%        4.000000      0.000000      1.000000      2.000000     26.24000
# max        4.000000      1.000000      1.000000      4.000000     41.00000
#
#               atemp      humidity     windspeed        casual    registered  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.000000
# mean      23.655084     61.886460     12.799395     36.021955    155.552177
# std        8.474601     19.245033      8.164537     49.960477    151.039033
# min        0.760000      0.000000      0.000000      0.000000      0.000000
# 25%       16.665000     47.000000      7.001500      4.000000     36.000000
# 50%       24.240000     62.000000     12.998000     17.000000    118.000000
# 75%       31.060000     77.000000     16.997900     49.000000    222.000000
# max       45.455000    100.000000     56.996900    367.000000    886.000000
#
#               count
# count  10886.000000
# mean     191.574132
# std      181.144454
# min        1.000000
# 25%       42.000000
# 50%      145.000000
# 75%      284.000000
# max      977.000000

# %% [markdown]
# * holiday | workingday : vacances | hors vacances et weekends => 0 ou 1 => No or Yes
# * season : saisons compris entre 1 et 4 => 4 saisons dans l'année
#      1 = spring, 2 = summer, 3 = fall, 4 = winter
# * weather : météo compris entre 1 et 4 => relatif au climat
#      * 1: Clear, Few clouds, Partly cloudy, Partly cloudy
#      * 2: Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist
#      * 3: Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain + Scattered clouds
#      * 4: Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog
# * temp : Températures comprises entre 0.82 et 41°C
# * atemp : températures ressenties entre 0.76 et 45.455°C
# * humidity : humidité relative comprise entre 0 et 100%
# * windspeed : vitesse du vent entre 0 et 57 (unité?)
# * casual : nombre de locations par  des utilisateurs non enregistrés/jour
# * registered : nombre de locations par  des utilisateurs enregistrés/jour
# * count : nombre de locations = casual + registered

# %% [markdown]
# ## Analyses des valeurs manquantes

# %%
df.isna().describe()
# Out:
#        datetime season holiday workingday weather   temp  atemp humidity  \
# count     10886  10886   10886      10886   10886  10886  10886    10886
# unique        1      1       1          1       1      1      1        1
# top       False  False   False      False   False  False  False    False
# freq      10886  10886   10886      10886   10886  10886  10886    10886
#
#        windspeed casual registered  count
# count      10886  10886      10886  10886
# unique         1      1          1      1
# top        False  False      False  False
# freq       10886  10886      10886  10886

# %% [markdown]
# Aucunes valeurs manquantes pour chaque features

# %% [markdown]
# ## Analyse répartition

# %%
df.hist(figsize=(25,15))
# Out:
# array([[<AxesSubplot:title={'center':'season'}>,
#         <AxesSubplot:title={'center':'holiday'}>,
#         <AxesSubplot:title={'center':'workingday'}>],
#        [<AxesSubplot:title={'center':'weather'}>,
#         <AxesSubplot:title={'center':'temp'}>,
#         <AxesSubplot:title={'center':'atemp'}>],
#        [<AxesSubplot:title={'center':'humidity'}>,
#         <AxesSubplot:title={'center':'windspeed'}>,
#         <AxesSubplot:title={'center':'casual'}>],
#        [<AxesSubplot:title={'center':'registered'}>,
#         <AxesSubplot:title={'center':'count'}>, <AxesSubplot:>]],
#       dtype=object)

# %% [markdown]
# weather : peu de donnèes pour temps très mauvais
# holiday : peu de donnèes pendant les jours de vacance
# Données bien réparties dans l'année (voir season)

# %%
print(" Nb de ligne :", len(df),"\n Test registered+casual :", df["count"][df["count"] == df["registered"]+df["casual"]].count())
# Out:
#  Nb de ligne : 10886
#  Test registered+casual : 10886

# %% [markdown]
# * Transformer datetime en jours
# * Fusion de weather 3 et 4 (mauvais temps) ?
# * Supprimer colonne count pour éviter redondance
# * Temp et Atemp peut-être corrélés

# %% [markdown]
# ## Valeurs abérantes

# %%
df.iloc[:,:5].boxplot(figsize=(25,15))
# Out:
# <AxesSubplot:>

# %%
df.iloc[:,5:9].boxplot(figsize=(25,15))
# Out:
# <AxesSubplot:>

# %%
df.iloc[:,9:].boxplot(figsize=(25,15))
# Out:
# <AxesSubplot:>

# %%
print("Nombre d'heures de vacances :", df["holiday"][df["holiday"]==1].count(),"\nRatio :", 100* df["holiday"][df["holiday"]==1].count()/df["holiday"].count())
# Out:
# Nombre d'heures de vacances : 311
# Ratio : 2.856880396839978

# %% [markdown]
# Supprimer colonne holiday ?

# %% [markdown]
# ## Analyses casual et registered

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
for col in df.drop(["datetime", "registered","count","casual"],axis=1).columns:
    plt.scatter(df[col], df["count"], label="Count")
    plt.legend()
    plt.title(f"Location en fonction de {col}")
    plt.show()

# %%
group_heure = df.groupby(["hour"]).mean().reset_index()

# %%
plt.scatter(group_heure["hour"],group_heure["count"])
plt.scatter(group_heure["hour"],group_heure["registered"])
plt.scatter(group_heure["hour"],group_heure["casual"])

# %%
df.groupby(["holiday"]).mean()
# Out:
#            season  workingday   weather       temp      atemp   humidity  \
# holiday
# 0        2.500993    0.700898  1.419196  20.230466  23.662662  61.880095
# 1        2.697749    0.000000  1.392283  20.244244  23.397395  62.102894
#
#          windspeed     casual  registered       count         year     month  \
# holiday
# 0        12.787623  35.646714  156.094941  191.741655  2011.500898  6.520473
# 1        13.199711  48.781350  137.096463  185.877814  2011.536977  6.556270
#
#                day       hour  dayofweek
# holiday
# 0        10.007470  11.542033   3.079905
# 1         9.485531  11.527331   0.771704

# %%
plt.scatter(range(0,df.shape[0]),df["count"])

# %% [markdown]
# ## Analyse corrélation

# %%
df['year'] = pd.to_datetime(df['datetime']).dt.year
df['month'] = pd.to_datetime(df['datetime']).dt.month
df['day'] = pd.to_datetime(df['datetime']).dt.day
df['hour'] = pd.to_datetime(df['datetime']).dt.hour
df['dayofweek'] = pd.to_datetime(df['datetime']).dt.weekday

# %%
df['date_data'] = df['year'].map(str)+ '-' +df['month'].map(str)
df['date_data'] = pd.to_datetime(df['date_data'], format='%Y-%m').dt.strftime('%Y-%m')

df_group_month_mean = df.groupby('date_data',as_index=False).mean()
df_group_month_count = df.groupby('date_data',as_index=False).count()
df_group_month_sum = df.groupby('date_data',as_index=False).sum()

# %%
plt.figure(figsize=(16,8))
sns.heatmap(df.corr(), annot=True)
plt.show()
